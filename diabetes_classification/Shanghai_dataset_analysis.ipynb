# %% [markdown]
# # Shanghai patients data analysis

# %% [markdown]
# ## Open the dataset and check the data

# %%
import pandas as pd

shanghai_T1DM = pd.read_excel("Shanghai_T1DM_Summary.xlsx")
shanghai_T1DM.describe()
# Out:
#        Gender (Female=1, Male=2)  Age (years)  Height (m)  Weight (kg)
# count                  16.000000    16.000000   16.000000     16.00000  \
# mean                    1.562500    59.000000    1.653750     57.78750
# std                     0.512348    10.152175    0.094225      9.47283
# min                     1.000000    37.000000    1.500000     35.00000
# 25%                     1.000000    56.000000    1.607500     52.12500
# 50%                     2.000000    58.500000    1.625000     60.00000
# 75%                     2.000000    67.250000    1.700000     64.25000
# max                     2.000000    73.000000    1.900000     74.00000
#
#        BMI (kg/m2)  Smoking History (pack year)
# count    16.000000                    16.000000  \
# mean     21.189323                    11.200000
# std       3.547238                    20.073365
# min      13.671875                     0.000000
# 25%      20.010739                     0.000000
# ...

# %%
shanghai_T1DM["BMI (kg/m2)"].plot.hist(bins=20, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# L'indice corporel moyen se situant entre 18,5 et 24,9, on peut considérer que les patients sont majoritairement en surpoids.
